# %%
import pandas as pd
df1 = pd.read_csv('dataset/payment_one.csv')
df2 = pd.read_csv('dataset/payment_two.csv')
max_id_in_df1 = df1['id'].max()
max_id_in_df1
df1
# Out:
#        id                 entity_id             name  \
# 0       1  651ba894fc13ae5a33fd63de     Tony Stather
# 1       2  651ba894fc13ae5a33fd63df      Berta Pietz
# 2       3  651ba894fc13ae5a33fd63e0    Idette Montes
# 3       4  651ba894fc13ae5a33fd63e1    Renie Verrier
# 4       5  651ba894fc13ae5a33fd63e2     Karlan Agney
# ..    ...                       ...              ...
# 995   996  651ba896fc13ae5a33fd67c1    Nikita Siflet
# 996   997  651ba896fc13ae5a33fd67c2    Lynnett Hands
# 997   998  651ba896fc13ae5a33fd67c3    Berty Conniam
# 998   999  651ba896fc13ae5a33fd67c4  Bale Davidovitz
# 999  1000  651ba896fc13ae5a33fd67c5     Nonah Durram
#
#                            email       ip_address  \
# 0         tstather0@engadget.com   104.149.14.236
# 1          bpietz1@delicious.com   253.198.94.115
# 2           imontes2@foxnews.com  128.215.163.145
# 3        rverrier3@over-blog.com   143.68.236.153
# 4             kagney4@flavors.me    42.244.173.17
# ...

# %%
df2['id'] = df2['id'] + max_id_in_df1
df2
# Out:
#        id                 entity_id                  name  \
# 0    1001  651ba8c0fc13ae594bfd7fd2     Marcelia McEvilly
# 1    1002  651ba8c0fc13ae594bfd7fd3       Reinhard Enbury
# 2    1003  651ba8c0fc13ae594bfd7fd4        Ettore Mohring
# 3    1004  651ba8c0fc13ae594bfd7fd5       Cally Fernandes
# 4    1005  651ba8c0fc13ae594bfd7fd6  Catharine De Coursey
# ..    ...                       ...                   ...
# 995  1996  651ba8c2fc13ae594bfd83b5         Netti Beining
# 996  1997  651ba8c2fc13ae594bfd83b6        Glenn Ibbotson
# 997  1998  651ba8c2fc13ae594bfd83b7      Merrick Eschelle
# 998  1999  651ba8c2fc13ae594bfd83b8          Emmy Lashley
# 999  2000  651ba8c2fc13ae594bfd83b9     Valentin Kennford
#
#                              email       ip_address  \
# 0     mmcevilly0@sciencedirect.com   22.241.188.166
# 1                renbury1@dell.com      27.22.38.27
# 2            emohring2@mozilla.org   162.64.136.238
# 3    cfernandes3@cocolog-nifty.com     44.129.31.40
# ...

# %%
combined_df = pd.concat([df1, df2], ignore_index=True)
combined_df
# Out:
#         id                 entity_id               name  \
# 0        1  651ba894fc13ae5a33fd63de       Tony Stather
# 1        2  651ba894fc13ae5a33fd63df        Berta Pietz
# 2        3  651ba894fc13ae5a33fd63e0      Idette Montes
# 3        4  651ba894fc13ae5a33fd63e1      Renie Verrier
# 4        5  651ba894fc13ae5a33fd63e2       Karlan Agney
# ...    ...                       ...                ...
# 1995  1996  651ba8c2fc13ae594bfd83b5      Netti Beining
# 1996  1997  651ba8c2fc13ae594bfd83b6     Glenn Ibbotson
# 1997  1998  651ba8c2fc13ae594bfd83b7   Merrick Eschelle
# 1998  1999  651ba8c2fc13ae594bfd83b8       Emmy Lashley
# 1999  2000  651ba8c2fc13ae594bfd83b9  Valentin Kennford
#
#                             email       ip_address  \
# 0          tstather0@engadget.com   104.149.14.236
# 1           bpietz1@delicious.com   253.198.94.115
# 2            imontes2@foxnews.com  128.215.163.145
# 3         rverrier3@over-blog.com   143.68.236.153
# ...

# %%
df3 = pd.read_csv('dataset/payment_three.csv')
df4 = pd.read_csv('dataset/payment_four.csv')
df5 = pd.read_csv('dataset/payment_five.csv')
max_id_in_combined = combined_df['id'].max()
max_id_in_combined
# Out:
# 2000

# %%
df3['id'] = df3['id'] + max_id_in_combined
df3
# Out:
#        id                 entity_id                name  \
# 0    2001  651ba902fc13ae585afd822a      Antonio Beynkn
# 1    2002  651ba902fc13ae585afd822b  Eleanora Antonazzi
# 2    2003  651ba902fc13ae585afd822c    Crystie Mainston
# 3    2004  651ba902fc13ae585afd822d          Rhea Found
# 4    2005  651ba902fc13ae585afd822e      Ardelle Pockey
# ..    ...                       ...                 ...
# 995  2996  651ba904fc13ae585afd860d     Araldo Riccardo
# 996  2997  651ba904fc13ae585afd860e         Kenny Drake
# 997  2998  651ba904fc13ae585afd860f         Geoffry Rix
# 998  2999  651ba904fc13ae585afd8610      Christian Ygoe
# 999  3000  651ba904fc13ae585afd8611   Elisabet Bleythin
#
#                              email       ip_address  \
# 0               abeynkn0@hc360.com      67.55.66.57
# 1       eantonazzi1@guardian.co.uk       1.96.76.57
# 2               cmainston2@loc.gov   177.133.239.10
# 3            rfound3@earthlink.net    103.114.48.39
# ...

# %%
combined_df = pd.concat([combined_df, df3], ignore_index=True)
combined_df
# Out:
#         id                 entity_id               name  \
# 0        1  651ba894fc13ae5a33fd63de       Tony Stather
# 1        2  651ba894fc13ae5a33fd63df        Berta Pietz
# 2        3  651ba894fc13ae5a33fd63e0      Idette Montes
# 3        4  651ba894fc13ae5a33fd63e1      Renie Verrier
# 4        5  651ba894fc13ae5a33fd63e2       Karlan Agney
# ...    ...                       ...                ...
# 2995  2996  651ba904fc13ae585afd860d    Araldo Riccardo
# 2996  2997  651ba904fc13ae585afd860e        Kenny Drake
# 2997  2998  651ba904fc13ae585afd860f        Geoffry Rix
# 2998  2999  651ba904fc13ae585afd8610     Christian Ygoe
# 2999  3000  651ba904fc13ae585afd8611  Elisabet Bleythin
#
#                               email       ip_address  \
# 0            tstather0@engadget.com   104.149.14.236
# 1             bpietz1@delicious.com   253.198.94.115
# 2              imontes2@foxnews.com  128.215.163.145
# 3           rverrier3@over-blog.com   143.68.236.153
# ...

# %%
max_id_in_combined = combined_df['id'].max()
max_id_in_combined
# Out:
# 3000

# %%
df4['id'] = df4['id'] + max_id_in_combined
df4
# Out:
#        id                 entity_id              name  \
# 0    3001  651ba917fc13ae58c1fd7dde      Julissa Uden
# 1    3002  651ba917fc13ae58c1fd7ddf  Trina Callingham
# 2    3003  651ba917fc13ae58c1fd7de0     Nert Banister
# 3    3004  651ba917fc13ae58c1fd7de1       Kiah Eastes
# 4    3005  651ba917fc13ae58c1fd7de2    Chicky Cheater
# ..    ...                       ...               ...
# 995  3996  651ba919fc13ae58c1fd81c1    Vincent Lebrun
# 996  3997  651ba919fc13ae58c1fd81c2   Chelsy De Roeck
# 997  3998  651ba919fc13ae58c1fd81c3     Deeyn Caherny
# 998  3999  651ba919fc13ae58c1fd81c4   Rodolphe Lawtey
# 999  4000  651ba919fc13ae58c1fd81c5   Hyacintha Darko
#
#                           email       ip_address  \
# 0     juden0@huffingtonpost.com   142.148.129.63
# 1        tcallingham1@yandex.ru     170.12.79.45
# 2       nbanister2@columbia.edu    80.238.20.180
# 3      keastes3@list-manage.com  205.195.114.206
# 4    ccheater4@surveymonkey.com   130.172.11.187
# ...

# %%
combined_df = pd.concat([combined_df, df4], ignore_index=True)
combined_df
# Out:
#         id                 entity_id             name  \
# 0        1  651ba894fc13ae5a33fd63de     Tony Stather
# 1        2  651ba894fc13ae5a33fd63df      Berta Pietz
# 2        3  651ba894fc13ae5a33fd63e0    Idette Montes
# 3        4  651ba894fc13ae5a33fd63e1    Renie Verrier
# 4        5  651ba894fc13ae5a33fd63e2     Karlan Agney
# ...    ...                       ...              ...
# 3995  3996  651ba919fc13ae58c1fd81c1   Vincent Lebrun
# 3996  3997  651ba919fc13ae58c1fd81c2  Chelsy De Roeck
# 3997  3998  651ba919fc13ae58c1fd81c3    Deeyn Caherny
# 3998  3999  651ba919fc13ae58c1fd81c4  Rodolphe Lawtey
# 3999  4000  651ba919fc13ae58c1fd81c5  Hyacintha Darko
#
#                            email       ip_address  \
# 0         tstather0@engadget.com   104.149.14.236
# 1          bpietz1@delicious.com   253.198.94.115
# 2           imontes2@foxnews.com  128.215.163.145
# 3        rverrier3@over-blog.com   143.68.236.153
# 4             kagney4@flavors.me    42.244.173.17
# ...

# %%
max_id_in_combined = combined_df['id'].max()
max_id_in_combined
# Out:
# 4000

# %%
df5['id'] = df5['id'] + max_id_in_combined
df5
# Out:
#        id                 entity_id                name  \
# 0    4001  651ba929fc13ae59ccfd68c6        Steven Warne
# 1    4002  651ba929fc13ae59ccfd68c7         Jammal Jost
# 2    4003  651ba929fc13ae59ccfd68c8  Clotilda Sterricks
# 3    4004  651ba929fc13ae59ccfd68c9     Booth Chasemore
# 4    4005  651ba929fc13ae59ccfd68ca      Rusty Sprosson
# ..    ...                       ...                 ...
# 995  4996  651ba92afc13ae59ccfd6ca9      Andeee Timpany
# 996  4997  651ba92afc13ae59ccfd6caa  Perrine MacCarrane
# 997  4998  651ba92afc13ae59ccfd6cab      Debby Bouchard
# 998  4999  651ba92afc13ae59ccfd6cac     Annmarie Cruise
# 999  5000  651ba92afc13ae59ccfd6cad    Zsa zsa Fontanet
#
#                            email       ip_address  \
# 0         swarne0@privacy.gov.au   89.171.253.185
# 1           jjost1@aboutads.info     95.83.99.180
# 2    csterricks2@stumbleupon.com  227.192.254.233
# 3       bchasemore3@springer.com   189.129.15.189
# ...

# %%
combined_df = pd.concat([combined_df, df5], ignore_index=True)
combined_df
# Out:
#         id                 entity_id                name  \
# 0        1  651ba894fc13ae5a33fd63de        Tony Stather
# 1        2  651ba894fc13ae5a33fd63df         Berta Pietz
# 2        3  651ba894fc13ae5a33fd63e0       Idette Montes
# 3        4  651ba894fc13ae5a33fd63e1       Renie Verrier
# 4        5  651ba894fc13ae5a33fd63e2        Karlan Agney
# ...    ...                       ...                 ...
# 4995  4996  651ba92afc13ae59ccfd6ca9      Andeee Timpany
# 4996  4997  651ba92afc13ae59ccfd6caa  Perrine MacCarrane
# 4997  4998  651ba92afc13ae59ccfd6cab      Debby Bouchard
# 4998  4999  651ba92afc13ae59ccfd6cac     Annmarie Cruise
# 4999  5000  651ba92afc13ae59ccfd6cad    Zsa zsa Fontanet
#
#                           email       ip_address  \
# 0        tstather0@engadget.com   104.149.14.236
# 1         bpietz1@delicious.com   253.198.94.115
# 2          imontes2@foxnews.com  128.215.163.145
# 3       rverrier3@over-blog.com   143.68.236.153
# ...

# %%
combined_df.to_csv('payment_combined.csv', index=False)

# %%
paydf=pd.read_csv('dataset/payment_combined.csv')
paydf
# Out:
#         id                 entity_id                name  \
# 0        1  651ba894fc13ae5a33fd63de        Tony Stather
# 1        2  651ba894fc13ae5a33fd63df         Berta Pietz
# 2        3  651ba894fc13ae5a33fd63e0       Idette Montes
# 3        4  651ba894fc13ae5a33fd63e1       Renie Verrier
# 4        5  651ba894fc13ae5a33fd63e2        Karlan Agney
# ...    ...                       ...                 ...
# 4995  4996  651ba92afc13ae59ccfd6ca9      Andeee Timpany
# 4996  4997  651ba92afc13ae59ccfd6caa  Perrine MacCarrane
# 4997  4998  651ba92afc13ae59ccfd6cab      Debby Bouchard
# 4998  4999  651ba92afc13ae59ccfd6cac     Annmarie Cruise
# 4999  5000  651ba92afc13ae59ccfd6cad    Zsa zsa Fontanet
#
#                           email       ip_address  \
# 0        tstather0@engadget.com   104.149.14.236
# 1         bpietz1@delicious.com   253.198.94.115
# 2          imontes2@foxnews.com  128.215.163.145
# 3       rverrier3@over-blog.com   143.68.236.153
# ...

# %%
paydf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  5000 non-null   int64
#  1   entity_id           5000 non-null   object
#  2   name                5000 non-null   object
#  3   email               5000 non-null   object
#  4   ip_address          5000 non-null   object
#  5   transaction_id      5000 non-null   object
#  6   transaction_amount  5000 non-null   object
#  7   transaction_limit   5000 non-null   int64
#  8   transaction_time    5000 non-null   object
#  9   transaction_status  5000 non-null   object
#  10  transaction_type    5000 non-null   object
#  11  payment_method      5000 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 468.9+ KB

# %%
paydf['transaction_amount'] = paydf['transaction_amount'].str.replace("$", "").astype(float)
paydf
# Out:
#         id                 entity_id                name  \
# 0        1  651ba894fc13ae5a33fd63de        Tony Stather
# 1        2  651ba894fc13ae5a33fd63df         Berta Pietz
# 2        3  651ba894fc13ae5a33fd63e0       Idette Montes
# 3        4  651ba894fc13ae5a33fd63e1       Renie Verrier
# 4        5  651ba894fc13ae5a33fd63e2        Karlan Agney
# ...    ...                       ...                 ...
# 4995  4996  651ba92afc13ae59ccfd6ca9      Andeee Timpany
# 4996  4997  651ba92afc13ae59ccfd6caa  Perrine MacCarrane
# 4997  4998  651ba92afc13ae59ccfd6cab      Debby Bouchard
# 4998  4999  651ba92afc13ae59ccfd6cac     Annmarie Cruise
# 4999  5000  651ba92afc13ae59ccfd6cad    Zsa zsa Fontanet
#
#                           email       ip_address  \
# 0        tstather0@engadget.com   104.149.14.236
# 1         bpietz1@delicious.com   253.198.94.115
# 2          imontes2@foxnews.com  128.215.163.145
# 3       rverrier3@over-blog.com   143.68.236.153
# ...

# %%
paydf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  5000 non-null   int64
#  1   entity_id           5000 non-null   object
#  2   name                5000 non-null   object
#  3   email               5000 non-null   object
#  4   ip_address          5000 non-null   object
#  5   transaction_id      5000 non-null   object
#  6   transaction_amount  5000 non-null   float64
#  7   transaction_limit   5000 non-null   int64
#  8   transaction_time    5000 non-null   object
#  9   transaction_status  5000 non-null   object
#  10  transaction_type    5000 non-null   object
#  11  payment_method      5000 non-null   object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 468.9+ KB

# %%
pd.options.display.max_rows = 9999
print(pd.options.display.max_rows)
# Out:
# 9999

# %%
pd.set_option('display.expand_frame_repr', False)

# %%
pd.options.display.max_rows = 60
print(pd.options.display.max_rows)
# Out:
# 60

# %%
paydf
# Out:
#         id                 entity_id                name                      email       ip_address                    transaction_id  transaction_amount  transaction_limit     transaction_time transaction_status      transaction_type payment_method
# 0        1  651ba894fc13ae5a33fd63de        Tony Stather     tstather0@engadget.com   104.149.14.236  b85157a79caf552696a0455659176ba0            91542.37              50000  2022-09-29 08:31:45             Failed      Loan Transaction         Cheque
# 1        2  651ba894fc13ae5a33fd63df         Berta Pietz      bpietz1@delicious.com   253.198.94.115  f54cb081ae7c5256a0d87390df95d295            37088.59              50000  2022-12-18 15:26:59             Failed      Loan Transaction     Debit Card
# ...

# %%
paydf.to_csv('dataset/payment_combined.csv', index=False)

# %%
newpaydf = pd.read_csv('dataset/payment_combined.csv')
newpaydf
# Out:
#         id                 entity_id                name                      email       ip_address                    transaction_id  transaction_amount  transaction_limit     transaction_time transaction_status      transaction_type payment_method
# 0        1  651ba894fc13ae5a33fd63de        Tony Stather     tstather0@engadget.com   104.149.14.236  b85157a79caf552696a0455659176ba0            91542.37              50000  2022-09-29 08:31:45             Failed      Loan Transaction         Cheque
# 1        2  651ba894fc13ae5a33fd63df         Berta Pietz      bpietz1@delicious.com   253.198.94.115  f54cb081ae7c5256a0d87390df95d295            37088.59              50000  2022-12-18 15:26:59             Failed      Loan Transaction     Debit Card
# ...

# %%
paydf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  5000 non-null   int64
#  1   entity_id           5000 non-null   object
#  2   name                5000 non-null   object
#  3   email               5000 non-null   object
#  4   ip_address          5000 non-null   object
#  5   transaction_id      5000 non-null   object
#  6   transaction_amount  5000 non-null   float64
#  7   transaction_limit   5000 non-null   int64
#  8   transaction_time    5000 non-null   object
#  9   transaction_status  5000 non-null   object
#  10  transaction_type    5000 non-null   object
#  11  payment_method      5000 non-null   object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 468.9+ KB

# %%
paydf
# Out:
#         id                 entity_id                name                      email       ip_address                    transaction_id  transaction_amount  transaction_limit     transaction_time transaction_status      transaction_type payment_method
# 0        1  651ba894fc13ae5a33fd63de        Tony Stather     tstather0@engadget.com   104.149.14.236  b85157a79caf552696a0455659176ba0            91542.37              50000  2022-09-29 08:31:45             Failed      Loan Transaction         Cheque
# 1        2  651ba894fc13ae5a33fd63df         Berta Pietz      bpietz1@delicious.com   253.198.94.115  f54cb081ae7c5256a0d87390df95d295            37088.59              50000  2022-12-18 15:26:59            Pending      Loan Transaction     Debit Card
# ...

# %%
import numpy as np
condition = paydf['transaction_amount'] > paydf['transaction_limit']
random_status = np.random.choice(['Pending', 'Failed'], size=condition.sum())
paydf.loc[condition, 'transaction_status'] = random_status

# %%
paydf['transaction_limit'] = paydf['transaction_limit'].astype(float)
paydf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  5000 non-null   int64
#  1   entity_id           5000 non-null   object
#  2   name                5000 non-null   object
#  3   email               5000 non-null   object
#  4   ip_address          5000 non-null   object
#  5   transaction_id      5000 non-null   object
#  6   transaction_amount  5000 non-null   float64
#  7   transaction_limit   5000 non-null   float64
#  8   transaction_time    5000 non-null   object
#  9   transaction_status  5000 non-null   object
#  10  transaction_type    5000 non-null   object
#  11  payment_method      5000 non-null   object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 468.9+ KB

# %%
condition
# Out:
# 0        True
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 4995     True
# 4996     True
# 4997    False
# 4998    False
# 4999    False
# Length: 5000, dtype: bool

# %%
pd.options.display.max_rows = 10

# %%
paydf
# Out:
#         id                 entity_id                name                      email       ip_address                    transaction_id  transaction_amount  transaction_limit     transaction_time transaction_status      transaction_type payment_method
# 0     1     651ba894fc13ae5a33fd63de  Tony Stather        tstather0@engadget.com     104.149.14.236   b85157a79caf552696a0455659176ba0  91542.37            50000.0            2022-09-29 08:31:45  Failed             Loan Transaction      Cheque
# 1     2     651ba894fc13ae5a33fd63df  Berta Pietz         bpietz1@delicious.com      253.198.94.115   f54cb081ae7c5256a0d87390df95d295  37088.59            50000.0            2022-12-18 15:26:59  Completed          Loan Transaction      Debit Card
# 2     3     651ba894fc13ae5a33fd63e0  Idette Montes       imontes2@foxnews.com       128.215.163.145  310c17c83691dbdcb32c5b633d760f81  13584.40            10000.0            2022-08-07 06:06:59  Failed             Loan Transaction      Cheque
# ...

# %%
paydf['transaction_id'].nunique()
# Out:
# 5000

# %%
paydf
# Out:
#         id                 entity_id                name                      email       ip_address                    transaction_id  transaction_amount  transaction_limit     transaction_time transaction_status      transaction_type payment_method
# 0     1     651ba894fc13ae5a33fd63de  Tony Stather        tstather0@engadget.com     104.149.14.236   b85157a79caf552696a0455659176ba0  91542.37            50000.0            2022-09-29 08:31:45  Failed             Loan Transaction      Cheque
# 1     2     651ba894fc13ae5a33fd63df  Berta Pietz         bpietz1@delicious.com      253.198.94.115   f54cb081ae7c5256a0d87390df95d295  37088.59            50000.0            2022-12-18 15:26:59  Completed          Loan Transaction      Debit Card
# 2     3     651ba894fc13ae5a33fd63e0  Idette Montes       imontes2@foxnews.com       128.215.163.145  310c17c83691dbdcb32c5b633d760f81  13584.40            10000.0            2022-08-07 06:06:59  Failed             Loan Transaction      Cheque
# ...

# %%
paydf.to_csv('dataset/payment_combined.csv', index=False)

# %%
import pandas as pd

# %%
df = pd.read_csv('dataset/payment_history.csv')
df
# Out:
#        Unnamed: 0  payer_account_number  payment_amount  payment_limit  \
# 0               0           93241136018        33154.19          10000
# 1               1           51702368715        19717.06          75000
# 2               2           75379272660        94456.98          50000
# 3               3           97412405333        90093.17          50000
# 4               4           97412405333        92000.51          25000
# ...           ...                   ...             ...            ...
# 49995       49995           76577126771        71198.98          25000
# 49996       49996            7335518416        80254.22          50000
# 49997       49997           81653666628        86319.48          75000
# 49998       49998           78817652976        56900.04          50000
# 49999       49999           87927980177         7925.49          50000
#
#             payment_date_and_time payment_type   payment_method  \
# ...

# %%
grouped = df.groupby('payer_account_number')
grouped

# %%
l = []
for payer, group in grouped:
    print(group['payment_amount'])
    l.append(group['payment_amount'])
len(l)
# Out:
# 191      85144.82
# 208      58925.42
# 217      95269.46
# 388      39311.14
# 465      37528.66
#            ...
# 49668    13831.75
# 49794    78736.55
# 49864    81962.63
# 49887    96781.90
# 49922    89565.99
# Name: payment_amount, Length: 1027, dtype: float64
# 45       81173.54
# 78       72153.19
# 150      42716.42
# 151       5528.11
# 220      22596.30
#            ...
# 49608    22908.13
# 49710    33943.38
# 49791    70079.12
# 49832    31175.98
# 49949    39901.62
# Name: payment_amount, Length: 984, dtype: float64
# 20       21378.99
# 96       66781.88
# 137      14879.54
# 143      78889.11
# 164      71969.07
#            ...
# 49840    36835.32
# 49860    64817.47
# 49872    23013.33
# 49912    40925.99
# 49934    79503.99
# Name: payment_amount, Length: 1003, dtype: float64
# 29       31122.02
# 93       78298.71
# 156      83359.98
# 189      97194.55
# 219       8718.68
#            ...
# 49760    65695.07
# 49838     7218.82
# 49950    56823.45
# ...
