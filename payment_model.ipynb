# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('dataset/payment_history.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   payer_account_number   50000 non-null  int64
#  1   payment_amount         50000 non-null  float64
#  2   payment_limit          50000 non-null  int64
#  3   payment_date_and_time  50000 non-null  object
#  4   payment_type           50000 non-null  object
#  5   payment_method         50000 non-null  object
#  6   payment_status         50000 non-null  object
#  7   payee_account_number   50000 non-null  int64
#  8   ip_address             50000 non-null  object
#  9   is_fraud               50000 non-null  bool
# dtypes: bool(1), float64(1), int64(3), object(5)
# memory usage: 3.5+ MB

# %%
df
# Out:
#        payer_account_number  payment_amount  payment_limit  \
# 0               93241136018        33154.19          10000
# 1               51702368715        19717.06          75000
# 2               75379272660        94456.98          50000
# 3               97412405333        90093.17          50000
# 4               97412405333        92000.51          25000
# ...                     ...             ...            ...
# 49995           76577126771        71198.98          25000
# 49996            7335518416        80254.22          50000
# 49997           81653666628        86319.48          75000
# 49998           78817652976        56900.04          50000
# 49999           87927980177         7925.49          50000
#
#             payment_date_and_time payment_type   payment_method  \
# 0      2023-10-08 15:53:43.255583      Service   Bank Transfers
# 1      2023-10-09 08:46:45.255583      Service  Digital Wallets
# ...

# %%
fraud_mapping = {False:0, True:1}
df['is_fraud'] = df['is_fraud'].map(fraud_mapping)
df
# Out:
#        payer_account_number  payment_amount  payment_limit  \
# 0               93241136018        33154.19          10000
# 1               51702368715        19717.06          75000
# 2               75379272660        94456.98          50000
# 3               97412405333        90093.17          50000
# 4               97412405333        92000.51          25000
# ...                     ...             ...            ...
# 49995           76577126771        71198.98          25000
# 49996            7335518416        80254.22          50000
# 49997           81653666628        86319.48          75000
# 49998           78817652976        56900.04          50000
# 49999           87927980177         7925.49          50000
#
#             payment_date_and_time payment_type   payment_method  \
# 0      2023-10-08 15:53:43.255583      Service   Bank Transfers
# 1      2023-10-09 08:46:45.255583      Service  Digital Wallets
# ...

# %%
status_mapping = {'Pending':1, 'Failed':2, 'Success': 3}
df['payment_status'] = df['payment_status'].map(status_mapping)
df
# Out:
#        payer_account_number  payment_amount  payment_limit  \
# 0               93241136018        33154.19          10000
# 1               51702368715        19717.06          75000
# 2               75379272660        94456.98          50000
# 3               97412405333        90093.17          50000
# 4               97412405333        92000.51          25000
# ...                     ...             ...            ...
# 49995           76577126771        71198.98          25000
# 49996            7335518416        80254.22          50000
# 49997           81653666628        86319.48          75000
# 49998           78817652976        56900.04          50000
# 49999           87927980177         7925.49          50000
#
#             payment_date_and_time payment_type   payment_method  \
# 0      2023-10-08 15:53:43.255583      Service   Bank Transfers
# 1      2023-10-09 08:46:45.255583      Service  Digital Wallets
# ...

# %%
y = df.is_fraud

# %%
payment_features = ['payer_account_number', 'payment_amount', 'payment_limit', 'payment_status']
X = df[payment_features]

# %%
from sklearn.model_selection import train_test_split

train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)

# %%
from sklearn.tree import DecisionTreeRegressor

payment_model = DecisionTreeRegressor(random_state=1)

payment_model.fit(train_X, train_y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
val_predictions = payment_model.predict(val_X)
val_predictions
# Out:
# array([0., 0., 0., ..., 0., 0., 1.])

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(val_y, val_predictions)
# Out:
# 0.00096

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(val_y, val_predictions)
accuracy
# Out:
# 0.99904
