# %%
import pandas as pd

# %%
my_path = 'C:/Users/MUNAWAR/Desktop/pandas/test.csv'

# %%
my_data = pd.read_csv(my_path)

# %%
my_data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  1459.000000  1459.000000  1232.000000   1459.000000  1459.000000
# mean   2190.000000    57.378341    68.580357   9819.161069     6.078821
# std     421.321334    42.746880    22.376841   4955.517327     1.436812
# min    1461.000000    20.000000    21.000000   1470.000000     1.000000
# 25%    1825.500000    20.000000    58.000000   7391.000000     5.000000
# 50%    2190.000000    50.000000    67.000000   9399.000000     6.000000
# 75%    2554.500000    70.000000    80.000000  11517.500000     7.000000
# max    2919.000000   190.000000   200.000000  56600.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1459.000000  1459.000000   1459.000000  1444.000000  1458.000000  ...
# mean      5.553804  1971.357779   1983.662783   100.709141   439.203704  ...
# std       1.113740    30.390071     21.130467   177.625900   455.268042  ...
# ...

# %%
my_data.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
my_data.Alley
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1454    NaN
# 1455    NaN
# 1456    NaN
# 1457    NaN
# 1458    NaN
# Name: Alley, Length: 1459, dtype: object

# %%
my_data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
features = ['Id', 'Street', 'Electrical', 'PoolArea', 'Fence']

# %%
X = my_data[features]

# %%
X.describe()
# Out:
#                 Id     PoolArea
# count  1459.000000  1459.000000
# mean   2190.000000     1.744345
# std     421.321334    30.491646
# min    1461.000000     0.000000
# 25%    1825.500000     0.000000
# 50%    2190.000000     0.000000
# 75%    2554.500000     0.000000
# max    2919.000000   800.000000

# %%
melb = 'C:/Users/MUNAWAR/Desktop/pandas/melb_data.csv'

# %%
melbdata = pd.read_csv(melb)

# %%
melbdata.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
feature = ['Rooms', 'Bathroom', 'Landsize', 'Lattitude', 'Longtitude']

# %%
X = melbdata[feature]

# %%
X.describe()
# Out:
#               Rooms      Bathroom       Landsize     Lattitude    Longtitude
# count  13580.000000  13580.000000   13580.000000  13580.000000  13580.000000
# mean       2.937997      1.534242     558.416127    -37.809203    144.995216
# std        0.955748      0.691712    3990.669241      0.079260      0.103916
# min        1.000000      0.000000       0.000000    -38.182550    144.431810
# 25%        2.000000      1.000000     177.000000    -37.856822    144.929600
# 50%        3.000000      1.000000     440.000000    -37.802355    145.000100
# 75%        3.000000      2.000000     651.000000    -37.756400    145.058305
# max       10.000000      8.000000  433014.000000    -37.408530    145.526350

# %%
X.head()
# Out:
#    Rooms  Bathroom  Landsize  Lattitude  Longtitude
# 0      2       1.0     202.0   -37.7996    144.9984
# 1      2       1.0     156.0   -37.8079    144.9934
# 2      3       2.0     134.0   -37.8093    144.9944
# 3      3       2.0      94.0   -37.7969    144.9969
# 4      4       1.0     120.0   -37.8072    144.9941

# %%
y = melbdata.Price

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
melbmodel = DecisionTreeRegressor(random_state=1)

# %%
melbmodel.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
print(X.head())
# Out:
#    Rooms  Bathroom  Landsize  Lattitude  Longtitude
# 0      2       1.0     202.0   -37.7996    144.9984
# 1      2       1.0     156.0   -37.8079    144.9934
# 2      3       2.0     134.0   -37.8093    144.9944
# 3      3       2.0      94.0   -37.7969    144.9969
# 4      4       1.0     120.0   -37.8072    144.9941

# %%
print(melbmodel.predict(X.head()))
# Out:
# [1480000. 1035000. 1465000.  850000. 1600000.]

# %%
fake = 'C:\Users\MUNAWAR\Desktop\pandas\fakename.csv'
# Out:
#   Cell In[46], line 1
#     fake = 'C:\Users\MUNAWAR\Desktop\pandas\fakename.csv'
#                                                          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
fake = 'C:/Users/MUNAWAR/Desktop/pandas/fakename.csv'

# %%
fakedata = pd.read_csv(fake)

# %%
print(fakedata)
# Out:
#    Id      Name   Label
# 0   1      John       1
# 1   2     David       0
# 2   3    Samuel       0
# 3   4   Gabrial       1
# 4   5     Luffy       1
# 5   6      Mark       0
# 6   7   Joffrey       1
# 7   8     Ronin       1
# 8   9      Alex       0

# %%
fakedata.describe()
# Out:
#              Id     Label
# count  9.000000  9.000000
# mean   5.000000  0.555556
# std    2.738613  0.527046
# min    1.000000  0.000000
# 25%    3.000000  0.000000
# 50%    5.000000  1.000000
# 75%    7.000000  1.000000
# max    9.000000  1.000000

# %%
fakedata = pd.read_csv(fake)

# %%
fakedata.describe()
# Out:
#              Id        Age     Label
# count  9.000000   9.000000  9.000000
# mean   5.000000  20.888889  0.555556
# std    2.738613   1.900292  0.527046
# min    1.000000  18.000000  0.000000
# 25%    3.000000  20.000000  0.000000
# 50%    5.000000  21.000000  1.000000
# 75%    7.000000  22.000000  1.000000
# max    9.000000  24.000000  1.000000

# %%
from sklearn.model_selection import train_test_split

# %%
print(fakedata)
# Out:
#    Id      Name   Age   Label
# 0   1      John    21       1
# 1   2     David    19       0
# 2   3    Samuel    20       0
# 3   4   Gabrial    22       1
# 4   5     Luffy    23       1
# 5   6      Mark    20       0
# 6   7   Joffrey    21       1
# 7   8     Ronin    24       1
# 8   9      Alex    18       0

# %%
mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

# %%
myvar = pd.DataFrame(mydataset)

# %%
print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
print(pd.__version__)
# Out:
# 2.1.1

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

# %%
result = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\MUNAWAR\Desktop\pandas\learning_pandas.ipynb Cell 38 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/MUNAWAR/Desktop/pandas/learning_pandas.ipynb#X52sZmlsZQ%3D%3D?line=0'>1</a> result = pd.DataFrame(data)
#
# NameError: name 'pd' is not defined

# %%
print(result)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
print(result.loc[[1,0]])
# Out:
#    calories  duration
# 1       380        40
# 0       420        50

# %%
new = 'C:/Users/MUNAWAR/Desktop/pandas/melb_data.csv'

# %%
data = pd.read_csv(new)
